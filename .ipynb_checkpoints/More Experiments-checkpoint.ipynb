# %% [markdown]
# Hi Kai,
#
# We need to run a few more experiments for the submission. The setup of these experiments are given in Table 1 of our draft. These models are available in either probabilistic-C or Anglican.
#
# The task is to
#
# - implement these models in Turing
# - run SMC on these models with 10K and 1M particles and report the running time
#
# This is quite important for the submission. Could you prioritise this over other task?
#
# Thanks,
#
# Hong

# %% [markdown]
# ### BIG-HMM

# %%
using Turing, Distributions

# %%
batch_size = 2
kilo = 100
mili = 1000
obs_size = 500
# Out:
# 1000

# %%
K = 10
N = obs_size + 1

T =  Array{Array{Float64}}(
  {{  2.72545164e-01,   6.56376310e-37,   7.93970182e-06,
          8.61092244e-05,   1.65656847e-01,   2.87081146e-01,
          2.18659173e-04,   4.06806091e-13,   2.74399041e-01,
          5.09466694e-06},
       {  8.35696383e-02,   7.05396766e-06,   2.06100213e-01,
          1.52600546e-11,   1.53908757e-08,   6.52698080e-11,
          6.73013596e-01,   1.93819808e-02,   1.79275025e-02,
          3.22727890e-18},
       {  8.86728867e-01,   8.63212428e-07,   3.94046562e-11,
          1.10467781e-01,   1.11735715e-06,   2.12946427e-18,
          5.16880247e-08,   2.36340361e-04,   1.11600188e-03,
          1.44897701e-03},
       {  8.16557898e-11,   1.68992485e-02,   6.27227283e-14,
          1.07672980e-02,   4.26756301e-01,   1.78050405e-09,
          6.41316248e-05,   3.21159984e-01,   3.69047216e-02,
          1.87448314e-01},
       {  1.30652141e-01,   4.70465408e-06,   4.73601393e-04,
          3.78509164e-02,   9.06618543e-10,   7.78622816e-04,
          2.93837790e-04,   8.29914494e-01,   8.69688804e-26,
          3.16817317e-05},
       {  2.23054659e-01,   2.88152163e-01,   7.35806925e-19,
          1.85562602e-02,   1.73073908e-08,   4.00936069e-01,
          1.17437994e-12,   4.43974641e-02,   2.49033671e-02,
          7.22022850e-18},
       {  4.78064507e-16,   3.20444079e-01,   3.85904296e-03,
          1.26156421e-09,   6.88364264e-03,   4.47186979e-03,
          1.56660567e-01,   1.69796226e-01,   3.33780163e-01,
          4.10440864e-03},
       {  4.84470444e-13,   2.50251630e-14,   2.78748146e-07,
          2.45132866e-03,   3.03033036e-12,   2.84425237e-03,
          8.49830551e-07,   6.60111797e-08,   9.94702713e-01,
          5.11768273e-07},
       {  1.68396450e-01,   1.80280379e-07,   5.68958062e-11,
          1.34838199e-01,   2.08104310e-04,   8.61188042e-02,
          5.17409105e-02,   3.61825373e-01,   3.31239961e-11,
          1.96871978e-01},
       {  4.74764005e-02,   1.16126593e-06,   5.96036112e-08,
          1.28470373e-03,   1.30134792e-06,   3.74283978e-02,
          3.10068428e-01,   2.27075277e-19,   6.47484474e-03,
          5.97264703e-01}})

obs = Array{Float64}(
  {         0.0,   7.72711051,   2.76189162,   8.8216901 ,
        10.80174329,   8.87655587,   0.47685358,   9.51892527,
         7.82538035,   5.52629325,  10.75167786,   5.94925434,
        -0.96912603,   1.65160838,   1.65005965,  -0.99642713,
         7.37803004,   5.40821392,   9.44046498,   8.51761132,
         9.76981763,   5.980154  ,   9.19558142,   5.33965621,
         6.2388448 ,   2.77755879,   6.67731151,   8.52411613,
        11.31057577,   8.11554144,   6.64705471,   8.02025435,
         9.84003587,   3.03943679,  -2.93966727,   2.04372567,
         6.2388448 ,   2.77755879,   6.67731151,   8.52411613,
        11.31057577,   8.11554144,   6.64705471,   8.02025435,
         9.84003587,   3.03943679,  -2.93966727,   2.04372567,
        -0.93734763,   3.66943525,   6.12876571,  -2.07758649,
         1.10420963,  -0.23197037,   3.64908206,  14.14671815,
         6.96651114,   7.28554932,   9.06049355,   6.54246834,
        11.22672275,   7.41962631,   8.45635411})

means = zeros(Float64,K)
initial = fill(1.0 / K, K)
for i = 1:K
  means[i] = i
end

@model big_hmm begin
  states = tzeros(Int,N)
  @assume states[1] ~ Categorical(initial)
  for i = 2:N
    @assume states[i] ~ Categorical(T[states[i-1]])
    @observe obs[i] ~ Normal(means[states[i]], 4)
  end
  @predict states
end
# Out:
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:8.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:12.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:16.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:20.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:24.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:28.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:32.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:36.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:40.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:44.
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}" at In[27]:44.
# Use "Any[a,b, ...]" instead.
#
# ...

# %%
big_hmm_10k = Float64[]
for _ in 1:batch_size
    push!(big_hmm_10k, @elapsed sample(big_hmm, SMC(kilo)))
end
println("[big_hmm_10k]: mean: $(mean(big_hmm_10k)), std: $(std(big_hmm_10k))")

big_hmm_1M = Float64[]
for _ in 1:batch_size
    push!(big_hmm_1M, @elapsed sample(big_hmm, SMC(mili)))
end
println("[big_hmm_1M]: mean: $(mean(big_hmm_1M)), std: $(std(big_hmm_1M))")
# Out:
# [big_hmm_10k]: mean: 0.704642892, std: 0.10158341273359937
# [big_hmm_1M]: mean: 6.4292657665, std: 0.5780433823787179

# %% [markdown]
# ### LINEAR-GAUSSIAN-1D

# %%
TT = obs_size

obs = Array{Float64}({ -1.20707157387629, 0.503699165203634, -1.70259337251950, -1.07701410185052, -4.20015625145706, -2.55438990317829, -2.88694661081943, -4.40447415469792, -3.81651098631986, -2.15054191207990, -3.87320140517147, -4.65399867465777, -4.26508970171536, -3.14697618846827, -3.60917468266110, -3.07249239739850, -5.04848080730519, -5.44188426787942, -6.61603453344347, -5.32349283632955, -2.99619527386241, -3.53678845221103, -2.64189362941369, 1.45816318303479, -2.02628921886034, -1.67116883723701, -2.61006571130934, -0.132727439342172, -2.50592100272724, -2.59957628660503, -2.59823005016528, -2.50377973112962, 0.154070601230415, -2.12846084927619, -0.826886102795848, -1.69889462610020
067269458265, -0.0280449001139889, -1.02140323226019, -0.392038555131002,-1.20707157387629, 0.503699165203634, -1.70259337251950, -1.07701410185052, -4.20015625145706, -2.55438990317829, -2.88694661081943, -4.40447415469792, -3.81651098631986, -2.15054191207990, -3.87320140517147, -4.65399867465777, -4.26508970171536, -3.14697618846827, -3.60917468266110, -3.07249239739850, -5.04848080730519, -5.44188426787942, -6.61603453344347, -5.32349283632955, -2.99619527386241, -3.53678845221103, -2.64189362941369, 1.45816318303479, -2.02628921886034, -1.67116883723701, -2.61006571130934, -0.132727439342172, -2.50592100272724, -2.59957628660503, -2.59823005016528, -2.50377973112962, 0.154070601230415, -2.12846084927619, -0.826886102795848, -1.69889462610020, 0.0282576381525715, 1.11518667015325, 2.26764785249174, 0.953894440382874, 0.716919703921550, 2.94790364504733, 1.28843368086306, -0.347295516164936, 0.890889951105044, -0.248679114600237, -0.819067269458265, -0.0280449001139889, -1.02140323226019, -0.392038555131002,-1.20707157387629, 0.503699165203634, -1.70259337251950, -1.07701410185052, -4.20015625145706, -2.55438990317829, -2.88694661081943, -4.40447415469792, -3.81651098631986, -2.15054191207990, -3.87320140517147, -4.65399867465777, -4.26508970171536, -3.14697618846827, -3.60917468266110, -3.07249239739850, -5.04848080730519, -5.44188426787942, -6.61603453344347, -5.32349283632955, -2.99619527386241, -3.53678845221103, -2.64189362941369, 1.45816318303479, -2.02628921886034, -1.67116883723701, -2.61006571130934, -0.132727439342172, -2.50592100272724, -2.59957628660503, -2.59823005016528, -2.50377973112962, 0.154070601230415, -2.12846084927619, -0.826886102795848, -1.69889462610020, 0.0282576381525715, 1.11518667015325, 2.26764785249174, 0.953894440382874, 0.716919703921550, 2.94790364504733, 1.28843368086306, -0.347295516164936, 0.890889951105044, -0.248679114600237, -0.819067269458265, -0.0280449001139889, -1.02140323226019, -0.392038555131002})


#     double path[TT] = { 0 };

#     double vo = 1;
#     double vx = 1;

#     for (int t=0; t<TT; t++) {
#         path[t] = normal_rng((t==0) ? 0 : path[t-1], vx);
#         observe(normal_lnp(observations[t], path[t], vo));
#         predict("state[%d],%0.8f\n", t, path[t]);
#     }

#     return 0;

vo = 1.0
vx = 1.0

@model linear_gaussian_1d begin
    path = tzeros(Float64,TT)
    @assume path[1] ~ Normal(0, vx)
  for i = 2:TT
        @assume path[i] ~ Normal(path[i - 1], vx)
    @observe obs[i] ~ Normal(path[i], vo)
  end
  @predict path
end
# Out:
# WARNING: deprecated syntax "{a,b, ...}" at In[29]:3.
# Use "Any[a,b, ...]" instead.
# linear_gaussian_1d (generic function with 1 method)

# %%
linear_gaussian_1d_10k = Float64[]
for _ in 1:batch_size
    push!(linear_gaussian_1d_10k, @elapsed sample(linear_gaussian_1d, SMC(kilo)))
end
println("[linear_gaussian_1d_10k]: mean: $(mean(linear_gaussian_1d_10k)), std: $(std(linear_gaussian_1d_10k))")

linear_gaussian_1d_1M = Float64[]
for _ in 1:batch_size
    push!(linear_gaussian_1d_1M, @elapsed sample(linear_gaussian_1d, SMC(mili)))
end
println("[linear_gaussian_1d_1M]: mean: $(mean(linear_gaussian_1d_1M)), std: $(std(linear_gaussian_1d_1M))")
# Out:
# [linear_gaussian_1d_10k]: mean: 0.5479561095000001, std: 0.021438957882091977
# [linear_gaussian_1d_1M]: mean: 5.776242233, std: 0.07523973099328013

# %% [markdown]
# ### MARSAGLIA

# %%
N = obs_size
mu = 3
sigma = 1

@model marsaglia begin
    rv = tzeros(N)
    for i in 1:N
        @assume x ~ Uniform(-1.0, 1.0)
        @assume y ~ Uniform(-1.0, 1.0)
        s = x * x + y * y
        while s >= 1 || s == 0
            x = rand( Uniform(-1.0, 1.0))
            y = rand( Uniform(-1.0, 1.0))
            s = x * x + y * y
        end

        s = sqrt(-2.0 * log(s) / s);
        spare = y * s;
        rv[i] = mu + sigma * x * s;
    end
    @predict rv
end
# Out:
# marsaglia (generic function with 1 method)

# %%
marsaglia_10k = Float64[]
for _ in 1:batch_size
    push!(marsaglia_10k, @elapsed sample(marsaglia, SMC(kilo)))
end
println("[marsaglia_10k]: mean: $(mean(marsaglia_10k)), std: $(std(marsaglia_10k))")

marsaglia_1M = Float64[]
for _ in 1:batch_size
    push!(marsaglia_1M, @elapsed sample(marsaglia, SMC(mili)))
end
println("[marsaglia_1M]: mean: $(mean(marsaglia_1M)), std: $(std(marsaglia_1M))")
# Out:
# [marsaglia_10k]: mean: 0.1387437805, std: 0.02379444512152288
# [marsaglia_1M]: mean: 1.188720762, std: 0.03368918335081756

# %% [markdown]
# ### BRANCHING

# %%
fib(n) = (n < 2) ? n : fib(n-1) + fib(n-2);

N = obs_size

obs = rand(1:10,N)

@model branching begin
    count_prior = Poisson(4)
    @assume r ~ Poisson(4)
    l = (4 < r) ? 6 : fib(3 * r) + rand(Poisson(4))
    for i in 1:500
        @observe obs[i] ~ Poisson(l)
    end
    @predict l
end
# Out:
# branching (generic function with 1 method)

# %%
branching_10k = Float64[]
for _ in 1:batch_size
    push!(branching_10k, @elapsed sample(branching, SMC(kilo)))
end
println("[branching_10k]: mean: $(mean(branching_10k)), std: $(std(branching_10k))")

branching_1M = Float64[]
for _ in 1:batch_size
    push!(branching_1M, @elapsed sample(branching, SMC(mili)))
end
println("[branching_1M]: mean: $(mean(branching_1M)), std: $(std(branching_1M))")
# Out:
# [branching_10k]: mean: 0.169861766, std: 0.02599013966343451
# [branching_1M]: mean: 1.638748833, std: 0.0034003718589225127

# %% [markdown]
# ### TRICKY-COIN

# %%
N = obs_size
obs = ones(N) # trickiest coin for ever!

@model tricky_coin begin
    @assume is_tricky ~ Bernoulli(0.1)
    theta = is_tricky == 1 ? rand(Beta(1, 1)) : 0.5

    for i in 1:N
        @observe obs[i] ~ Bernoulli(theta)
    end
    
    @predict is_tricky theta
end
# Out:
# tricky_coin (generic function with 1 method)

# %%
tricky_coin_10k = Float64[]
for _ in 1:batch_size
    push!(tricky_coin_10k, @elapsed sample(tricky_coin, SMC(kilo)))
end
println("[tricky_coin_10k]: mean: $(mean(tricky_coin_10k)), std: $(std(tricky_coin_10k))")

tricky_coin_1M = Float64[]
for _ in 1:batch_size
    push!(tricky_coin_1M, @elapsed sample(tricky_coin, SMC(mili)))
end
println("[tricky_coin_1M]: mean: $(mean(tricky_coin_1M)), std: $(std(tricky_coin_1M))")
# Out:
# [tricky_coin_10k]: mean: 0.091900185, std: 0.024098425377007515
# [tricky_coin_1M]: mean: 0.898593653, std: 0.006684008873552476
